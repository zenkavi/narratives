# %%
wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
bash Miniconda3-latest-Linux-x86_64.sh

# %%
conda create -n datalad_env python=3.12
conda activate datalad_env
conda install -c conda-forge datalad
conda update -c conda-forge datalad

# %%
conda install -c conda-forge ca-certificates certifi
export SSL_CERT_FILE=$(python -c "import certifi; print(certifi.where())")
git config --global http.sslCAInfo $(python -c "import certifi; print(certifi.where())")

# %%
cd /hopper/groups/enkavilab/data/
datalad clone https://github.com/OpenNeuroDatasets/ds004892.git
datalad get derivatives/preprocessing/sub-S01/ses-1
